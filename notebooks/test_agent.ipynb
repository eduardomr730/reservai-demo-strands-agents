# %%
from agent import agent_manager

# %%
# Simular dos usuarios diferentes
user1 = "whatsapp:+34612345678"
user2 = "whatsapp:+34687654321"

# %%
print("=" * 50)
print("USUARIO 1 - Primera conversación")
print("=" * 50)
response = agent_manager.process_message(user1, "Hola, quiero hacer una reserva")
print(f"Bot: {response}\n")

response = agent_manager.process_message(user1, "Para mañana a las 21:00, somos 4 personas")
print(f"Bot: {response}\n")

print("=" * 50)
print("USUARIO 2 - Conversación independiente")
print("=" * 50)
response = agent_manager.process_message(user2, "Qué horarios tenéis?")
print(f"Bot: {response}\n")

print("=" * 50)
print("USUARIO 1 - Continúa su conversación")
print("=" * 50)
response = agent_manager.process_message(user1, "Mi nombre es Juan Pérez, teléfono 612345678")
print(f"Bot: {response}\n")
# Out:
# ...
# USUARIO 1 - Primera conversación
# ...
# ✅ Nuevo agente creado para: 34612345678
# ¡Hola y bienvenido/a a El Rincón de Andalucía! 👋🇪🇸
#
# ¡Estupendo! Estaré encantado de ayudarte con tu reserva. 📅
#
# Para poder registrar tu solicitud, necesito los siguientes datos:
#
# 1. **¿Para qué fecha?** (por ejemplo: 2024-03-15)
# 2. **¿A qué hora?** (recuerda nuestros horarios: Mar-Vie 13:00-16:00 y 20:00-23:30, Sáb 13:00-00:00, Dom 13:00-18:00)
# 3. **¿Cuántas personas?**
# 4. **Tu nombre completo**
# 5. **Teléfono de contacto**
# 6. **¿Alguna ocasión especial?** (cumpleaños, aniversario, etc.)
# 7. **¿Preferencias?** (terraza, mesa interior, alergias, etc.)
#
# ¡Cuéntame los detalles y preparo tu reserva! 🍽️✨Bot: ¡Hola y bienvenido/a a El Rincón de Andalucía! 👋🇪🇸
#
# ¡Estupendo! Estaré encantado de ayudarte con tu reserva. 📅
#
# Para poder registrar tu solicitud, necesito los siguientes datos:
#
# 1. **¿Para qué fecha?** (por ejemplo: 2024-03-15)
# ...
